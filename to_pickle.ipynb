# %%
import pickle as pkl
import pandas as pd

# %%
data = pd.read_csv("./Data/crsp_us.csv")

# %%
data = data.rename(columns={"DlyCalDt": "Date"})
data["Date"] = pd.to_datetime(data["Date"])

# %%
data = data.drop(columns=['HdrCUSIP', 'PERMCO'])

# %%
data.isna().sum()
# Out:
# ticker          0
# PERMNO          0
# Date            0
# DlyVol        738
# DlyClose    84650
# DlyLow      84650
# DlyHigh     84650
# DlyOpen     84655
# dtype: int64

# %%
data = data.dropna().copy()

# %%
#Only keep stocks for which trading information is available on all 2768 trading days in the analyzed timeframe

counts = data['PERMNO'].value_counts()

valid_permnos = counts[counts == 2768].index

# Filter the dataframe
data = data[data['PERMNO'].isin(valid_permnos)]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2726480 entries, 0 to 6663735
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   ticker    object
#  1   PERMNO    int64
#  2   Date      datetime64[ns]
#  3   DlyVol    float64
#  4   DlyClose  float64
#  5   DlyLow    float64
#  6   DlyHigh   float64
#  7   DlyOpen   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 187.2+ MB

# %%
with open('./Data/stocks.pkl', 'wb') as file:
    pkl.dump(data, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 with open('./ML_Finance/Data/stocks.pkl', 'wb') as file:
#       2     pkl.dump(data, file)
#
# File ~/Documents/Universität_Tübingen/3.Semester_Michigan/ML_Finance_Project/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './ML_Finance/Data/stocks.pkl'
